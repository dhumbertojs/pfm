# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.metrics import silhouette_score, davies_bouldin_score
import matplotlib.pyplot as plt
import unidecode

# %%
data = pd.read_csv("../data/clean_data.csv", index_col=0)

# %%
# Descargar recursos necesarios para NLTK
nltk.download('stopwords')
nltk.download('punkt')

# Función para preprocesar y limpiar el texto
def preprocess_text(text):
    # Eliminar caracteres especiales y puntuaciones
    text = re.sub(r'[^\w\s]', '', text)
    
    # Convertir el texto a minúsculas
    text = unidecode.unidecode(text.lower())
    
    # Tokenizar el texto (dividir en palabras)
    words = nltk.word_tokenize(text)
    
    # Eliminar palabras irrelevantes (stopwords)
    stop_words = set(stopwords.words('spanish'))
    words = [word for word in words if word not in stop_words]
    
    return ' '.join(words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dhumb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dhumb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
data["descripcion_limpia"] = data["descripcion_solicitud"].apply(preprocess_text)

# %%
data.to_csv("../data/clean_data_py.csv", index=False)

# %%
data
# Out:
#                     fecha_de_ingreso                  dependencia  \
# folio
# '100000000106    2006-10-31 10:46:03         Jefatura de Gobierno
# '100000000107    2007-01-09 00:00:00         Jefatura de Gobierno
# '100000000108    2008-01-02 15:19:33         Jefatura de Gobierno
# '100000000109    2009-01-03 01:33:06         Jefatura de Gobierno
# '100000000110    2010-01-02 20:18:26         Jefatura de Gobierno
# ...                              ...                          ...
# '92880522000043  2022-12-14 13:44:06  Servicio de Medios Públicos
# '92880522000044  2022-12-14 17:49:55  Servicio de Medios Públicos
# '92880522000045  2022-12-15 14:05:19  Servicio de Medios Públicos
# '92880522000046  2022-12-21 16:36:11  Servicio de Medios Públicos
# '92880522000047  2022-12-21 19:25:34  Servicio de Medios Públicos
#
#                                                 organo_de_gobierno  \
# folio
# '100000000106                       Administración Pública Central
# '100000000107                       Administración Pública Central
# '100000000108                       Administración Pública Central
# '100000000109                       Administración Pública Central
# '100000000110                       Administración Pública Central
# ...                                                            ...
# '92880522000043  Organismos desconcentrados, descentralizados, ...
# '92880522000044  Organismos desconcentrados, descentralizados, ...
# '92880522000045  Organismos desconcentrados, descentralizados, ...
# '92880522000046  Organismos desconcentrados, descentralizados, ...
# '92880522000047  Organismos desconcentrados, descentralizados, ...
#
#                                              descripcion_solicitud  \
# folio
# '100000000106    En la administraciòn 20002006 del Gobierno del...
# '100000000107    Indiqueme cuantas veces se sometió a la mesa d...
# '100000000108    disculpen soloquisiera saber como va el proces...
# '100000000109    1. Se solicita copia simple de todas las pauta...
# '100000000110    Requiero1. Cuántos regalos llegaron a la Ofici...
# ...                                                            ...
# '92880522000043  SOLICITUD DE INFORMACIÓNFavor de proporcionar ...
# '92880522000044  Solicito conocer cuál fue el costo de grabació...
# '92880522000045  El motivo del siguiente correo electrónico bus...
# '92880522000046  Solicito Organigrama del 2020, 2021 y 2022, as...
# '92880522000047  Solicito me informen Computadoras de escritori...
#
#                                  estatus medio_entrada  \
# folio
# '100000000106                  Terminada   Electrónica
# '100000000107                  Terminada   Electrónica
# '100000000108                  Terminada   Electrónica
# '100000000109                  Terminada   Electrónica
# '100000000110                  Terminada   Electrónica
# ...                                  ...           ...
# '92880522000043  En proceso con prórroga   Electrónica
# '92880522000044                Terminada   Electrónica
# '92880522000045                Terminada        Manual
# '92880522000046               En proceso   Electrónica
# '92880522000047               En proceso   Electrónica
#
#                                                        otros_datos  \
# folio
# '100000000106                                                  NaN
# '100000000107                                                  NaN
# '100000000108                                                  NaN
# '100000000109                                                  NaN
# '100000000110                                                  NaN
# ...                                                            ...
# '92880522000043                                                NaN
# '92880522000044  https://twitter.com/Claudiashein/status/160287...
# '92880522000045                                                NaN
# '92880522000046                                                NaN
# '92880522000047                                                NaN
#
#                 fecha_limite_de_respuesta  \
# folio
# '100000000106                  2006-11-15
# '100000000107                  2007-01-22
# '100000000108                  2008-01-21
# '100000000109                  2009-02-24
# '100000000110                  2010-02-22
# ...                                   ...
# '92880522000043                2023-01-19
# '92880522000044                2022-12-28
# '92880522000045                2022-12-28
# '92880522000046                2023-01-18
# '92880522000047                2023-01-18
#
#                                                          respuesta  \
# folio
# '100000000106                       Notificación de no competencia
# '100000000107                       Notificación de no competencia
# '100000000108                       Notificación de no competencia
# '100000000109             Prepare y entregue información con pago.
# '100000000110                    Recibe la notificación de entrega
# ...                                                            ...
# '92880522000043                                Ampliación de plazo
# '92880522000044  Notoria incompetencia por la totalidad de la i...
# '92880522000045  Entrega de información vía plataforma nacional...
# '92880522000046                           Registro de la solicitud
# '92880522000047                           Registro de la solicitud
#
#                                              texto_de_la_respuesta    pais  \
# folio
# '100000000106                                                  NaN  Mexico
# '100000000107                                                  NaN     NaN
# '100000000108                                                  NaN     NaN
# '100000000109    La información se encuentra a su disposición e...  Mexico
# '100000000110    Hacemos de su conocimiento que su solicitud de...  Mexico
# ...                                                            ...     ...
# '92880522000043  AMPLIACIÓN DE PLAZO: Se anexa oficio SMPCDMX/D...     NaN
# '92880522000044  Por este medio se da respuesta de la solicitud...     NaN
# '92880522000045  Por este medio se envía respuesta de Folio 092...     NaN
# '92880522000046                                                NaN     NaN
# '92880522000047                                                NaN     NaN
#
#                            estado      fecha_respuesta  \
# folio
# '100000000106    Distrito Federal                  NaN
# '100000000107                 NaN  2007-01-04 19:24:00
# '100000000108                 NaN  2008-01-18 19:51:31
# '100000000109    Distrito Federal  2009-02-18 19:43:16
# '100000000110    Distrito Federal  2010-02-22 17:17:08
# ...                           ...                  ...
# '92880522000043               NaN                  NaN
# '92880522000044               NaN                  NaN
# '92880522000045               NaN                  NaN
# '92880522000046               NaN                  NaN
# '92880522000047               NaN                  NaN
#
#                                                 descripcion_limpia
# folio
# '100000000106    administracion 20002006 gobierno distrito fede...
# '100000000107    indiqueme cuantas veces sometio mesa asuntos l...
# '100000000108    disculpen soloquisiera saber va proceso introd...
# '100000000109    1 solicita copia simple todas pautas publicita...
# '100000000110    requiero1 cuantos regalos llegaron oficina jef...
# ...                                                            ...
# '92880522000043  solicitud informacionfavor proporcionar medio ...
# '92880522000044  solicito conocer costo grabacion produccion ed...
# '92880522000045  motivo siguiente correo electronico busca escl...
# '92880522000046  solicito organigrama 2020 2021 2022 asi curric...
# '92880522000047  solicito informen computadoras escritorio port...
#
# [1604132 rows x 14 columns]
